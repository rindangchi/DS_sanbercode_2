# %%
import tweepy
import pandas as pd
import csv

#persiapan key

token_data = open('data_key.csv')
tokens = csv.reader(token_data, delimiter=',')

data_token = [row[2] for row in tokens]
consumer_key = data_token[0]
consumer_secret = data_token[1]
access_token = data_token[2]
access_token_secret = data_token[3]

#handler autentikasi
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

#retrive tweet kompas
tweet_kompas = api.user_timeline(id = 'kompascom', count= 50, tweet_mode='extended')
df_kompas = pd.DataFrame(data=[tweet.full_text for tweet in tweet_kompas], columns=['Kompascom'])
#print(df_kompas)

#retrive tweet pikiran_rakyat
tweet_pikiranr = api.user_timeline(id = 'pikiran_rakyat', count= 50, tweet_mode='extended')
df_pikiranr = pd.DataFrame(data=[tweet.full_text for tweet in tweet_pikiranr], columns=['Pikiranrakyat'])
#print(df_pikiranr)

#combine tweet
df_all = pd.concat([df_kompas, df_pikiranr], axis = 1, sort = False)
print(df_all)

#save to csv
df_all.to_csv('tweet_berita.csv', index = False)

# %%
for tweet in tweepy.Cursor(api.search, q='topik yang dicari -filter:retweets',lang="id", since='2019-10-13', until='2019-10-14').items(2000):
	text = tweet.text
	user = tweet.user.name
 	tanggal = tweet.created_at
 	print("tweet ="+text)
 	print("user = "+user)
 	print("tanggal = "+tanggal)

# %%
import tweepy
import pandas as pd
import csv
from tweepy import Stream

#persiapan key

token_data = open('data_key.csv')
tokens = csv.reader(token_data, delimiter=',')

data_token = [row[2] for row in tokens]
consumer_key = data_token[0]
consumer_secret = data_token[1]
access_token = data_token[2]
access_token_secret = data_token[3]

#handler autentikasi
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

f = open('keywords.txt', 'r')
search = f.read().splitlines()
f.close()
  

numberoftweets = 10
for x in search: #goes through each keyword
    x = x +' -filter:retweets'
    for tweet in tweepy.Cursor(api.search, q= x, lang= 'id', since='2020-12-24', until ='2020-12-25').items(numberoftweets):
      #tweet_data
      tweetid = tweet.id
      text = tweet.text
      userid = tweet.user.id
      tanggal = tweet.created_at

      #user_data
      user_id = tweet.user.id
      username = tweet.user.name
      screenname = tweet.user.screen_name
      location = tweet.user.location
      acc_created_at = tweet.user.created_at
      follower = tweet.user.followers_count
      friend = tweet.user.friends_count
      verified = tweet.user.verified
      

      print("tweet ="+text)
      print("user ="+username)
      print("tanggal = "+str(tanggal))
      print("userid = "+str(userid))
      print("screenname = "+screenname)
      print("location= "+location)
      print("acc_created_date= "+str(acc_created_at))
      print("follower= "+str(follower))
      print("friend= "+str(friend))
      print("verified= "+str(verified))
# Out:
# tweet =@raehankhrlajri @SiaranBolaLive Maap lg psbb wkwk
# user =Si_Farhan
# tanggal = 2020-12-24 23:49:15
# userid = 1205078485796040704
# screenname = SiFarhan5
# location=
# acc_created_date= 2019-12-12 10:55:10
# follower= 33
# friend= 60
# verified= False
# tweet =@CNNIndonesia Pemerintah sebenarnya yg tidak disiplin, skli tolak karantina pilih PSBB, giliran ada lawan politik p… https://t.co/CF7ItEz5Xj
# user =Daeng Lewa
# tanggal = 2020-12-24 23:48:05
# userid = 235517680
# screenname = lewa_samawa
# location=
# acc_created_date= 2011-01-08 11:40:51
# follower= 22
# friend= 114
# verified= False
# tweet =IDEAS Sebut PSBB Jilid Dua di Jakarta Mampu Turunkan Angka Positif Harian Corona hingga 23 Persen https://t.co/bz1BIyjAJt
# user =Andhika Bayu
# tanggal = 2020-12-24 23:38:32
# userid = 606022374
# screenname = ElBeppe
# location= Jakarta - Depok
# acc_created_date= 2012-06-12 02:27:43
# follower= 103
# friend= 265
# verified= False
# ...

# %%
import tweepy
import pandas as pd
import csv
from tweepy import Stream

#persiapan key

token_data = open('data_key.csv')
tokens = csv.reader(token_data, delimiter=',')

data_token = [row[2] for row in tokens]
consumer_key = data_token[0]
consumer_secret = data_token[1]
access_token = data_token[2]
access_token_secret = data_token[3]

#handler autentikasi
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

f = open('keywords.txt', 'r')
search = f.read().splitlines()
f.close()
  

numberoftweets = 10

for x in search: #goes through each keyword
    x = x +' -filter:retweets'
    for tweet in tweepy.Cursor(api.search, q= x, lang= 'id', since='2020-12-24', until ='2020-12-25', tweet_mode= 'extended').items(numberoftweets):
      tweet_data = [[tweet.id, tweet.full_text, tweet.user.id, tweet.created_at, tweet.user.name, tweet.user.screen_name, tweet.user.location, tweet.user.created_at, tweet.user.followers_count
               , tweet.user.friends_count, tweet.user.verified ]]
print(tweet_data)
# Out:
# [[1341972286249852929, 'Jaga jarak bukan cuman saat makan di gerai, tapi juga setiap saat, termasuk saat tunggu orderan ya!\nJadi bebas khawatir deh kalau senantiasa jaga jarak! 😉\n\n#kfcindonesia #KFCSepenuhHati #physicaldistancing #psbb #jagajarak https://t.co/hgAzh8eqzc', 124053465, datetime.datetime(2020, 12, 24, 5, 1, 40), 'KFC Jagonya Ayam!', 'KFCINDONESIA', 'Indonesia', datetime.datetime(2010, 3, 18, 3, 32, 24), 340266, 3, True]]

# %%
import tweepy
import pandas as pd
import csv
from tweepy import Stream

#persiapan key

token_data = open('data_key.csv')
tokens = csv.reader(token_data, delimiter=',')

data_token = [row[2] for row in tokens]
consumer_key = data_token[0]
consumer_secret = data_token[1]
access_token = data_token[2]
access_token_secret = data_token[3]

#handler autentikasi
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

f = open('keywords.txt', 'r')
search = f.read().splitlines()
f.close()

numberoftweets = 10


for x in search:   #goes through each keyword
  x = x +' -filter:retweets'
  tweet_list = tweepy.Cursor(api.search, q= x, lang= 'id', since='2020-12-24', until ='2020-12-25', tweet_mode='extended').items(numberoftweets)
print(tweet_list)
  #tweet_data = [[tweet.id, tweet.full_text, tweet.user.id, tweet.created_at, tweet.user.name, tweet.user.screen_name, tweet.user.location, tweet.user.created_at, tweet.user.followers_count
               #, tweet.user.friends_count, tweet.user.verified ] for tweet in tweet_list]

#tweet_data

# %%
import tweepy
import pandas as pd
import csv
from tweepy import Stream

#persiapan key

token_data = open('data_key.csv')
tokens = csv.reader(token_data, delimiter=',')

data_token = [row[2] for row in tokens]
consumer_key = data_token[0]
consumer_secret = data_token[1]
access_token = data_token[2]
access_token_secret = data_token[3]

#handler autentikasi
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

f = open('keywords.txt', 'r')
search = f.read().splitlines()
f.close()

numberoftweets = 200

tweet_list = tweepy.Cursor(api.search, q= 'PSBB OR psbb OR #PSBB OR #psbb OR "Pembatasan Sosial Berskala Besar" OR "pembatasan sosial berskala besar" -filter:retweets', lang= 'id', since='2020-12-24', until ='2020-12-25', tweet_mode='extended').items(numberoftweets)
tweet_data = [[tweet.id, tweet.user.id, tweet.created_at, tweet.full_text, tweet.user.name, tweet.user.screen_name, tweet.user.location, tweet.user.created_at, tweet.user.followers_count
               , tweet.user.friends_count, tweet.user.verified ] for tweet in tweet_list]

tweet_data

tweet_df_1 = pd.DataFrame(data=tweet_data, columns=['tweetid', "userid", "createddate", "tweet", "name", "screenname", "location", "accountcreated", "follower","friend", "verified"])
tweet_df_1

# %%
import tweepy
import pandas as pd
import csv
from tweepy import Stream

#persiapan key

token_data = open('data_key.csv')
tokens = csv.reader(token_data, delimiter=',')

data_token = [row[2] for row in tokens]
consumer_key = data_token[0]
consumer_secret = data_token[1]
access_token = data_token[2]
access_token_secret = data_token[3]

#handler autentikasi
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

f = open('keywords.txt', 'r')
search = f.read().splitlines()
f.close()

numberoftweets = 200

tweet_list = tweepy.Cursor(api.search, q= 'PSBB OR psbb OR #PSBB OR #psbb OR "Pembatasan Sosial Berskala Besar" OR "pembatasan sosial berskala besar" -filter:retweets', lang= 'id', since='2020-12-25', until ='2020-12-26', tweet_mode='extended').items(numberoftweets)
tweet_data = [[tweet.id, tweet.user.id, tweet.created_at, tweet.full_text, tweet.user.name, tweet.user.screen_name, tweet.user.location, tweet.user.created_at, tweet.user.followers_count
               , tweet.user.friends_count, tweet.user.verified] for tweet in tweet_list]

tweet_data

tweet_df_2 = pd.DataFrame(data=tweet_data, columns=['tweetid', "userid", "createddate", "tweet", "name", "screenname", "location", "accountcreated", "follower","friend", "verified"])
tweet_df_2

# %%
import tweepy
import pandas as pd
import csv
from tweepy import Stream

#persiapan key

token_data = open('data_key.csv')
tokens = csv.reader(token_data, delimiter=',')

data_token = [row[2] for row in tokens]
consumer_key = data_token[0]
consumer_secret = data_token[1]
access_token = data_token[2]
access_token_secret = data_token[3]

#handler autentikasi
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

f = open('keywords.txt', 'r')
search = f.read().splitlines()
f.close()

numberoftweets = 200

tweet_list = tweepy.Cursor(api.search, q= 'PSBB OR psbb OR #PSBB OR #psbb OR "Pembatasan Sosial Berskala Besar" OR "pembatasan sosial berskala besar" -filter:retweets', lang= 'id', since='2020-12-26', until ='2020-12-27', tweet_mode='extended').items(numberoftweets)
tweet_data = [[tweet.id, tweet.user.id, tweet.created_at, tweet.full_text, tweet.user.name, tweet.user.screen_name, tweet.user.location, tweet.user.created_at, tweet.user.followers_count
               , tweet.user.friends_count, tweet.user.verified ] for tweet in tweet_list]

tweet_data

tweet_df_3 = pd.DataFrame(data=tweet_data, columns=['tweetid', "userid", "createddate", "tweet", "name", "screenname", "location", "accountcreated", "follower","friend", "verified"])
tweet_df_3

# %%
import tweepy
import pandas as pd
import csv
from tweepy import Stream

#persiapan key

token_data = open('data_key.csv')
tokens = csv.reader(token_data, delimiter=',')

data_token = [row[2] for row in tokens]
consumer_key = data_token[0]
consumer_secret = data_token[1]
access_token = data_token[2]
access_token_secret = data_token[3]

#handler autentikasi
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

f = open('keywords.txt', 'r')
search = f.read().splitlines()
f.close()

numberoftweets = 200

tweet_list = tweepy.Cursor(api.search, q= 'PSBB OR psbb OR #PSBB OR #psbb OR "Pembatasan Sosial Berskala Besar" OR "pembatasan sosial berskala besar" -filter:retweets', lang= 'id', since='2020-12-27', until ='2020-12-28', tweet_mode='extended').items(numberoftweets)
tweet_data = [[tweet.id, tweet.user.id, tweet.created_at, tweet.full_text, tweet.user.name, tweet.user.screen_name, tweet.user.location, tweet.user.created_at, tweet.user.followers_count
               , tweet.user.friends_count, tweet.user.verified] for tweet in tweet_list]

tweet_data

tweet_df_4 = pd.DataFrame(data=tweet_data, columns=['tweetid', "userid", "createddate", "tweet", "name", "screenname", "location", "accountcreated", "follower","friend", "verified"])
tweet_df_4

# %%
import tweepy
import pandas as pd
import csv
from tweepy import Stream

#persiapan key

token_data = open('data_key.csv')
tokens = csv.reader(token_data, delimiter=',')

data_token = [row[2] for row in tokens]
consumer_key = data_token[0]
consumer_secret = data_token[1]
access_token = data_token[2]
access_token_secret = data_token[3]

#handler autentikasi
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

f = open('keywords.txt', 'r')
search = f.read().splitlines()
f.close()

numberoftweets = 200

tweet_list = tweepy.Cursor(api.search, q= 'PSBB OR psbb OR #PSBB OR #psbb OR "Pembatasan Sosial Berskala Besar" OR "pembatasan sosial berskala besar" -filter:retweets', lang= 'id', since='2020-12-28', until ='2020-12-29', tweet_mode='extended').items(numberoftweets)
tweet_data = [[tweet.id, tweet.user.id, tweet.created_at, tweet.full_text, tweet.user.name, tweet.user.screen_name, tweet.user.location, tweet.user.created_at, tweet.user.followers_count
               , tweet.user.friends_count, tweet.user.verified ] for tweet in tweet_list]

tweet_data
tweet_df_5 = pd.DataFrame(data=tweet_data, columns=['tweetid', "userid", "createddate", "tweet", "name", "screenname", "location", "accountcreated", "follower","friend", "verified"])
tweet_df_5

# %%
frames = [tweet_df_1, tweet_df_2, tweet_df_3, tweet_df_4, tweet_df_5]

merge_df = pd.concat(frames)

merge_df.head()

# %%
#split dataframs

df_tweet_data = merge_df.iloc[:,[0,1,2,3]]  
df_tweet_data

df_user_data = merge_df.iloc[:,[1,4,5,6,7,8,9,10]]  

df_tweet_data

# %%
df_user_data = df_user_data.drop_duplicates(subset=['userid'])

# %%
df_user_data

# %%
df_user_data.to_csv('df_user_data.csv', index=False)

# %%
df_tweet_data.to_csv('df_tweet_data.csv', index=False)

# %%
#sql connection
import sqlite3
from sqlalchemy import create_engine
engine = create_engine('sqlite:///test1.db', echo=False)

# %%
df_tweet_data.to_sql('Tweet', if_exists = 'append', con=engine, index=False, chunksize = 1000)

# %%
df_user_data.to_sql('User', if_exists = 'append', con=engine, index=False, chunksize = 1000)

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///for_test_.db', echo=False)
